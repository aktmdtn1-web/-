# %%
# 불 자료형은 어떻게 사용할까?
a = True
b = False
print(a)
print(b)

print(type(a))
print(type(b))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %%
# or 연산자
print(True or True)
print(True or False)
print(False or True)
# Out:
# True
