# %%
# 숫자형은 어떻게 만들고 사용할까?

a = 1234
b = -1234
c = 0

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# 1234
# -1234
# 0
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
# 실수형
a = 1.2
b = -3.14

print(a)
print(b)

print(type(a))
print(type(b))
# Out:
# 1.2
# -3.14
# <class 'float'>
# <class 'float'>

# %%
# 8진수와 16진수

a = 0o177
print(a)
b = 1234

print(1*(8 **2) + 7*(8**1) + 7*(8**0))
# Out:
# 127
# 127

# %%
a = 0x8ff
print(a)
# Out:
# 2303

# %%
# 사칙 연산
a = 3
b = 4

print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
# x의 y 제곱을 나타내는 연산자

a = 3
b = 4

(a ** b)
# Out:
# 81

# %%
# 나눗셈 후 나머지는 반환하는 연산자
print(7/3)
print(7%3)
# Out:
# 2.3333333333333335
# 1

# %%
# 나눗셈 후 몫을 반환하는 연산자

print(7/3)
print(7//3)
# Out:
# 2.3333333333333335
# 2

# %%
# 복합연산자

a = 3

# a = a + 1
a += 1

print(a)
# Out:
# 4

# %%
# a=3 
# b=2
