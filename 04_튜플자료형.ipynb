# %%
# 튜플 만들기 예시
empty_tuple = ()
numbers = (1, 2, 3)
words = "hello", "world"
single_item = ("python",)

print(empty_tuple)
print(numbers)
print(words)
print(single_item)

# %%
# eㄷ

# %%
# 튜플은 어떻게 만들까? (tuple)
t1 = ()
t2 = (1, )
t3 = (1, 2, 3)
t4 = 1, 2, 3
